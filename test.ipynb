# %%
import yfinance as yf
import pandas as pd
import os

# 🔹 Step 1: Define NIFTY 50 stocks
nifty50_stocks = list(set([
    "POWERGRID.NS", "HINDUNILVR.NS", "INFY.NS", "NESTLEIND.NS", "ITC.NS", "ASIANPAINT.NS", "CIPLA.NS",
    "SUNPHARMA.NS", "SBILIFE.NS", "HDFCBANK.NS", "JSWSTEEL.NS", "ICICIBANK.NS", "NTPC.NS", "BHARTIARTL.NS",
    "HINDALCO.NS", "AXISBANK.NS", "TATAMOTORS.NS", "HDFCLIFE.NS", "BAJAJFINSV.NS", "TECHM.NS", "BRITANNIA.NS",
    "HCLTECH.NS", "TATASTEEL.NS", "ADANIPORTS.NS", "TCS.NS", "TATACONSUM.NS", "SBIN.NS", "MARUTI.NS",
    "KOTAKBANK.NS", "GRASIM.NS", "BAJFINANCE.NS", "SHRIRAMFIN.NS", "RELIANCE.NS", "ULTRACEMCO.NS",
    "ADANIENT.NS", "M&M.NS", "APOLLOHOSP.NS", "DRREDDY.NS", "WIPRO.NS", "COALINDIA.NS", "TITAN.NS",
    "BEL.NS", "BPCL.NS", "HEROMOTOCO.NS", "LT.NS", "EICHERMOT.NS", "BAJAJ-AUTO.NS", "INDUSINDBK.NS",
    "TRENT.NS", "ONGC.NS"
]))

# 🔹 Step 2: Create a new folder for storing data
folder_name = "NIFTY50_Data"
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# 🔹 Step 3: Download, clean, and save data for each stock
for ticker in nifty50_stocks:
    print(f"📥 Fetching data for {ticker}...")

    # Download stock data
    # df = yf.download(ticker, start="2020-03-12", end="2025-03-12")˚`
    df = yf.download(ticker, start="2025-01-10", end="2025-03-12", interval="1h")

    # Keep only OHLCV and reset index
    df = df[['Open', 'High', 'Low', 'Close', 'Volume']]
    df.reset_index(inplace=True)

    # Save to a temporary CSV
    temp_filename = f"temp_{ticker}.csv"
    df.to_csv(temp_filename, index=False)

    # Reload and clean data
    df = pd.read_csv(temp_filename)
    df.drop(index=0, inplace=True)  # Remove first row
    df.reset_index(inplace=True)
    df.drop(columns=["index"], axis=1, inplace=True)  # Remove extra index column

    # Save cleaned data inside the new folder
    final_filename = os.path.join(folder_name, f"{ticker.replace('.NS', '')}_NIFTY.csv")
    df.to_csv(final_filename, index=False)

    # Remove the temporary CSV
    os.remove(temp_filename)

    print(f"✅ Saved: {final_filename}")

print("🎉 All NIFTY 50 stock data processed successfully!")
# Out:
# 📥 Fetching data for BRITANNIA.NS...
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/BRITANNIA_NIFTY.csv
# 📥 Fetching data for HDFCBANK.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/HDFCBANK_NIFTY.csv
# 📥 Fetching data for MARUTI.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/MARUTI_NIFTY.csv
# 📥 Fetching data for INDUSINDBK.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/INDUSINDBK_NIFTY.csv
# 📥 Fetching data for TATAMOTORS.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/TATAMOTORS_NIFTY.csv
# 📥 Fetching data for NTPC.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/NTPC_NIFTY.csv
# 📥 Fetching data for INFY.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/INFY_NIFTY.csv
# 📥 Fetching data for AXISBANK.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/AXISBANK_NIFTY.csv
# 📥 Fetching data for TCS.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/TCS_NIFTY.csv
# 📥 Fetching data for TRENT.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/TRENT_NIFTY.csv
# 📥 Fetching data for SBILIFE.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/SBILIFE_NIFTY.csv
# 📥 Fetching data for HINDALCO.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/HINDALCO_NIFTY.csv
# 📥 Fetching data for ASIANPAINT.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/ASIANPAINT_NIFTY.csv
# 📥 Fetching data for BAJFINANCE.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/BAJFINANCE_NIFTY.csv
# 📥 Fetching data for TATASTEEL.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/TATASTEEL_NIFTY.csv
# 📥 Fetching data for COALINDIA.NS...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/COALINDIA_NIFTY.csv
# 📥 Fetching data for BPCL.NS...
# ✅ Saved: NIFTY50_Data/BPCL_NIFTY.csv
# 📥 Fetching data for CIPLA.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/CIPLA_NIFTY.csv
# 📥 Fetching data for ICICIBANK.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/ICICIBANK_NIFTY.csv
# 📥 Fetching data for M&M.NS...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/M&M_NIFTY.csv
# 📥 Fetching data for SHRIRAMFIN.NS...
# ✅ Saved: NIFTY50_Data/SHRIRAMFIN_NIFTY.csv
# 📥 Fetching data for BAJAJ-AUTO.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/BAJAJ-AUTO_NIFTY.csv
# 📥 Fetching data for LT.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/LT_NIFTY.csv
# 📥 Fetching data for HDFCLIFE.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/HDFCLIFE_NIFTY.csv
# 📥 Fetching data for ADANIPORTS.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/ADANIPORTS_NIFTY.csv
# 📥 Fetching data for NESTLEIND.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/NESTLEIND_NIFTY.csv
# 📥 Fetching data for ULTRACEMCO.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/ULTRACEMCO_NIFTY.csv
# 📥 Fetching data for SUNPHARMA.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/SUNPHARMA_NIFTY.csv
# 📥 Fetching data for APOLLOHOSP.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/APOLLOHOSP_NIFTY.csv
# 📥 Fetching data for JSWSTEEL.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/JSWSTEEL_NIFTY.csv
# 📥 Fetching data for BHARTIARTL.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/BHARTIARTL_NIFTY.csv
# 📥 Fetching data for DRREDDY.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/DRREDDY_NIFTY.csv
# 📥 Fetching data for WIPRO.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/WIPRO_NIFTY.csv
# 📥 Fetching data for EICHERMOT.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/EICHERMOT_NIFTY.csv
# 📥 Fetching data for ONGC.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/ONGC_NIFTY.csv
# 📥 Fetching data for KOTAKBANK.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/KOTAKBANK_NIFTY.csv
# 📥 Fetching data for ITC.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/ITC_NIFTY.csv
# 📥 Fetching data for TECHM.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/TECHM_NIFTY.csv
# 📥 Fetching data for HCLTECH.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/HCLTECH_NIFTY.csv
# 📥 Fetching data for ADANIENT.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/ADANIENT_NIFTY.csv
# 📥 Fetching data for HINDUNILVR.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/HINDUNILVR_NIFTY.csv
# 📥 Fetching data for RELIANCE.NS...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/RELIANCE_NIFTY.csv
# 📥 Fetching data for BEL.NS...
# ✅ Saved: NIFTY50_Data/BEL_NIFTY.csv
# 📥 Fetching data for BAJAJFINSV.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/BAJAJFINSV_NIFTY.csv
# 📥 Fetching data for TATACONSUM.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/TATACONSUM_NIFTY.csv
# 📥 Fetching data for SBIN.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/SBIN_NIFTY.csv
# 📥 Fetching data for TITAN.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/TITAN_NIFTY.csv
# 📥 Fetching data for HEROMOTOCO.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/HEROMOTOCO_NIFTY.csv
# 📥 Fetching data for GRASIM.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/GRASIM_NIFTY.csv
# 📥 Fetching data for POWERGRID.NS...
# [*********************100%***********************]  1 of 1 completed
# ✅ Saved: NIFTY50_Data/POWERGRID_NIFTY.csv
# 🎉 All NIFTY 50 stock data processed successfully!

# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

# 🔹 Step 1: Load all CSV files
folder_name = "NIFTY50_Data"
all_files = [f for f in os.listdir(folder_name) if f.endswith(".csv")]

# 🔹 Step 2: Create an empty DataFrame to store closing prices
closing_prices = pd.DataFrame()

# 🔹 Step 3: Merge all closing prices
for file in all_files:
    stock_name = file.replace("_NIFTY.csv", "")  # Extract stock name from filename
    file_path = os.path.join(folder_name, file)
    
    df = pd.read_csv(file_path, usecols=["Datetime", "Close"])  # Read only Datetime and Close
    df.rename(columns={"Close": stock_name}, inplace=True)  # Rename 'Close' column to stock name

    # Convert 'Datetime' to Unix timestamp
    df["Datetime"] = pd.to_datetime(df["Datetime"])
    df["Datetime"] = df["Datetime"].astype(int) // 10**9  # Convert to Unix timestamp (seconds)

    if closing_prices.empty:
        closing_prices = df  # Initialize with first stock
    else:
        closing_prices = pd.merge(closing_prices, df, on="Datetime", how="outer")  # Merge on 'Datetime'

# 🔹 Step 4: Set 'Datetime' as index
closing_prices.set_index("Datetime", inplace=True)

# 🔹 Step 5: Compute the correlation matrix
correlation_matrix = closing_prices.corr()

# 🔹 Step 6: Extract pairs with correlation > 0.9
corr_threshold = 0.9
high_corr_pairs = (
    correlation_matrix.where((correlation_matrix > corr_threshold) & (correlation_matrix < 1.0))
    .stack()
    .reset_index()
)

high_corr_pairs.columns = ["Stock_1", "Stock_2", "Correlation"]
high_corr_pairs = high_corr_pairs.sort_values(by="Correlation", ascending=False).drop_duplicates()

# 🔹 Step 7: Save results to CSV
high_corr_pairs.to_csv("high_corr_pairs.csv", index=False)

# 🔹 Step 8: Plot heatmap
plt.figure(figsize=(20, 20))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix of NIFTY 50 Closing Prices")
plt.show()

# 🔹 Step 9: Display top highly correlated pairs
print(high_corr_pairs.head(20))
# Out:
#        Stock_1     Stock_2  Correlation
# 4         ONGC          LT     0.958359
# 13          LT        ONGC     0.958359
# 23   POWERGRID          LT     0.948785
# 15          LT   POWERGRID     0.948785
# 37  HEROMOTOCO       TITAN     0.944922
# 35       TITAN  HEROMOTOCO     0.944922
# 6         ONGC   POWERGRID     0.943516
# 22   POWERGRID        ONGC     0.943516
# 27  APOLLOHOSP        ONGC     0.940731
# 7         ONGC  APOLLOHOSP     0.940731
# 28  APOLLOHOSP         ITC     0.932073
# 31         ITC  APOLLOHOSP     0.932073
# 5         ONGC  TATAMOTORS     0.930035
# 17  TATAMOTORS        ONGC     0.930035
# 34       TITAN         ITC     0.926035
# 32         ITC       TITAN     0.926035
# 29    JSWSTEEL   TATASTEEL     0.924795
# 3    TATASTEEL    JSWSTEEL     0.924795
# 8          TCS   SUNPHARMA     0.923478
# 0    SUNPHARMA         TCS     0.923478

# %%
import pandas as pd
import os
from statsmodels.tsa.stattools import coint, adfuller

# 🔹 Step 1: Load high correlation pairs
high_corr_pairs = pd.read_csv("high_corr_pairs.csv")

# 🔹 Step 2: Load all closing prices
folder_name = "NIFTY50_Data"
all_files = [f for f in os.listdir(folder_name) if f.endswith(".csv")]

# Create a dictionary to store closing prices
closing_prices = {}

for file in all_files:
    stock_name = file.replace("_NIFTY.csv", "")  # Extract stock name
    file_path = os.path.join(folder_name, file)
    
    df = pd.read_csv(file_path, usecols=["Datetime", "Close"])
    df.rename(columns={"Close": stock_name}, inplace=True)
    
    # Convert to datetime only if necessary
    if not pd.api.types.is_datetime64_any_dtype(df["Datetime"]):
        df["Datetime"] = pd.to_datetime(df["Datetime"])  # Auto-detect format

    closing_prices[stock_name] = df.set_index("Datetime")  # Store in dict with 'Datetime' as index

# 🔹 Step 3: Run Cointegration & Stationarity Tests
cointegrated_pairs = []

for _, row in high_corr_pairs.iterrows():
    stock1, stock2 = row["Stock_1"], row["Stock_2"]
    
    if stock1 in closing_prices and stock2 in closing_prices:
        # Merge on Datetime
        merged_df = closing_prices[stock1].join(closing_prices[stock2], how="inner")
        
        # Drop NaN values
        merged_df.dropna(inplace=True)
        
        # Run Engle-Granger Cointegration Test
        coint_score, coint_p_value, _ = coint(merged_df[stock1], merged_df[stock2])
        
        # Run ADF Stationarity Test on Individual Stocks
        adf_stock1_p = adfuller(merged_df[stock1])[1]
        adf_stock2_p = adfuller(merged_df[stock2])[1]
        
        # Check thresholds
        if coint_p_value < 0.04:
            cointegrated_pairs.append([stock1, stock2, coint_p_value, adf_stock1_p, adf_stock2_p])

# 🔹 Step 4: Save Results
cointegrated_df = pd.DataFrame(cointegrated_pairs, 
                               columns=["Stock_1", "Stock_2", "Cointegration P-Value", "Stock1 ADF P-Value", "Stock2 ADF P-Value"])
cointegrated_df.to_csv("cointegrated_pairs.csv", index=False)

# 🔹 Step 5: Display Results
print(cointegrated_df.head(20))
# Out:
#       Stock_1     Stock_2  Cointegration P-Value  Stock1 ADF P-Value  \
# 0          LT        ONGC               0.028259            0.726980
# 1  HEROMOTOCO       TITAN               0.029212            0.902303
# 2       TITAN  HEROMOTOCO               0.022858            0.712388
# 3  APOLLOHOSP        ONGC               0.001254            0.603263
# 4        ONGC  APOLLOHOSP               0.001888            0.751929
# 5  APOLLOHOSP         ITC               0.013808            0.603263
# 6         ITC  APOLLOHOSP               0.018794            0.755497
# 7  TATAMOTORS          LT               0.009554            0.623327
# 8          LT  TATAMOTORS               0.007267            0.726980
#
#    Stock2 ADF P-Value
# 0            0.751929
# 1            0.712388
# 2            0.902303
# 3            0.751929
# 4            0.603263
# 5            0.755497
# 6            0.603263
# 7            0.726980
# 8            0.623327

# %%
import numpy as np
cointegrated_pairs
plt.figure(figsize=(15,15))

for i,val in enumerate(cointegrated_pairs):
    df1 = pd.read_csv(f"NIFTY50_Data/{val[0]}_NIFTY.csv")
    df2 = pd.read_csv(f"NIFTY50_Data/{val[1]}_NIFTY.csv")
    
    plt.subplot(4,3,i+1)
    plt.plot(df1.Close - df2.Close)
    # plt.plot(df1.Close/df2.Close)
    plt.title(f"{val[0]} - {val[1]}")

# %%
import numpy as np
cointegrated_pairs
plt.figure(figsize=(15,15))

for i,val in enumerate(cointegrated_pairs):
    df1 = pd.read_csv(f"NIFTY50_Data/{val[0]}_NIFTY.csv")
    df2 = pd.read_csv(f"NIFTY50_Data/{val[1]}_NIFTY.csv")
    
    plt.subplot(4,3,i+1)
    # plt.plot(df1.Close - df2.Close)
    plt.plot(np.log(df1.Close/df2.Close))
    plt.title(f"{val[0]}/{val[1]}")
